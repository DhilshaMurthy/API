# %% [markdown]
# <a href="https://colab.research.google.com/github/DhilshaMurthy19/API/blob/main/Copy_of_Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rembg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 53.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.0 MB/s eta 0:00:00
# ...

# %%
# !pip install pillow==7.1.2

# %%
from rembg import remove
from PIL import Image

# %%
input_path = r'/content/nameLogo.png'
output_path = r'/content/nameLogoBGR.png'

input = Image.open(input_path)
output = remove(input)
output.save(output_path)
# Out:
# ...
# 100%|███████████████████████████████████████| 176M/176M [00:00<00:00, 55.1GB/s]

# %%
from IPython.display import Image, display
display(Image('/content/nameLogo.png'))

# %%
from IPython.display import Image, display
display(Image('/content/nameLogoBGR.png'))
